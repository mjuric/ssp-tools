# %%
import pandas as pd

df = pd.read_parquet('../obs_sbn.parquet')

# %%
df
# Out:
#                id   trksub       trkid                      obsid  \
# 0       567799394  cb02280  00000IsfE7  LorDdACC0000Gugo0100015hz
# 1       567799395  cb02280  00000IsfE7  LorDdACC0000Gugo0100015i0
# 2       567799396  cb02280  00000IsfE7  LorDdACC0000Gugo0100015i1
# 3       567799397  cb02280  00000IsfE7  LorDdACC0000Gugo0100015i2
# 4       567799398  cb02280  00000IsfE7  LorDdACC0000Gugo0100015i3
# ...           ...      ...         ...                        ...
# 733171  567593465  cb00505  00000Iseza  LorDdACC0000Gugo010000E8Y
# 733172  567593466  cb00505  00000Iseza  LorDdACC0000Gugo010000E8Z
# 733173  567849707  cb03059  00000IsfKv  LorDdACC0000Gugo010001InU
# 733174  567835535  cb02802  00000IsfIf  LorDdACC0000Gugo010001F6u
# 733175  567812209  cb02437  00000IsfFW  LorDdACC0000Gugo01000192g
#
#                            submission_id                  submission_block_id  \
# 0       2025-06-23T14:33:20.756_0000Gugo  2025-06-23T14:33:20.756_0000Gugo_01
# ...
